# %%
import pandas as pd

# %%
# df = pd.read_csv('C:\\Users\\23470\\Downloads\\archiver\\bj\\products.csv')
df = pd.read_csv('C:\\Users\\23470\\Downloads\\archiver\\bj\\products.csv', na_values='NaN', keep_default_na=False)
df
# Out:
#       key                                  name  \
# 0    0_bj                   Salted Caramel Core
# 1    1_bj                   Netflix & Chilll'd™
# 2    2_bj                          Chip Happens
# 3    3_bj                               Cannoli
# 4    4_bj                        Gimme S’more!™
# 5    5_bj             Peanut Butter Half Baked®
# 6    6_bj                Berry Sweet Mascarpone
# 7    7_bj         Chocolate Peanut Butter Split
# 8    8_bj                     Justice ReMix'd ™
# 9    9_bj                 Boots on the Moooo’n™
# 10  10_bj                      Americone Dream®
# 11  11_bj                     Bourbon Pecan Pie
# 12  12_bj                     Brewed to Matter™
# 13  13_bj          Caramel Chocolate Cheesecake
# 14  14_bj                        Cherry Garcia®
# 15  15_bj                   Chillin' the Roast™
# 16  16_bj           Chocolate Chip Cookie Dough
# 17  17_bj               Chocolate Fudge Brownie
# ...

# %%
# df.head(10)
# df['key'].head(10)
# df['key']
# df.shape
# df.columns
# df.loc[[0, 1, 2],'ingredients']
# filt = df['name'].str.contains('Cannoli', na=False)
# df['description']
# df.columns
# filt = df.at[40, 'description']
# filt

# filt =df.at[5,'rating_count']
# filt
# Out:
#     key                           name  \
# 0  0_bj            Salted Caramel Core
# 1  1_bj            Netflix & Chilll'd™
# 2  2_bj                   Chip Happens
# 3  3_bj                        Cannoli
# 4  4_bj                 Gimme S’more!™
# 5  5_bj      Peanut Butter Half Baked®
# 6  6_bj         Berry Sweet Mascarpone
# 7  7_bj  Chocolate Peanut Butter Split
# 8  8_bj              Justice ReMix'd ™
# 9  9_bj          Boots on the Moooo’n™
#
#                                              subhead  \
# 0  Sweet Cream Ice Cream with Blonde Brownies & a...
# 1  Peanut Butter Ice Cream with Sweet & Salty Pre...
# 2  A Cold Mess of Chocolate Ice Cream with Fudge ...
# 3  Mascarpone Ice Cream with Fudge-Covered Pastry...
# 4  Toasted Marshmallow Ice Cream with Chocolate C...
# 5  Chocolate & Peanut Butter Ice Creams Mixed wit...
# 6  Blackberry & Mascarpone Ice Creams with Shortb...
# 7  Chocolate & Banana Ice Creams with Mini Peanut...
# ...

# %%
# df.loc[filt, 'name' ]

# %%
# df['rating'].value_counts()
